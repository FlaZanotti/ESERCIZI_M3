# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## ESERCIZIO 1
#
# Estraiamo la tabella dimproduct dal database AdventureWorks, e valutiamo quanto segue:
# - Quanti dati ci sono in totale?
# - Quali sono i metadati?
# - Stampiamo il primo elemento
# - Stampiamo l'ultimo elemento
# - Riusciamo a stampare cinque elementi a caso?
# - Quali sono i colori disponibili?
# - In media quanto pesano i prodotti (per questo esercizio, ignoriamo l'unità di misura, ma usiamo solo i valori della colonna relativa)?
# - Quanto pesa il più leggero?
# - Quanto pesa il più pesante?
# - Quanti prodotti pesano più di 100?
# - Quanto costano in media i prodotti (colonna DealerPrice)?
# - Quali sono i quartili dei prezzi?
# - Qual è il prezzo medio per i prodotti di colore blu?
# - Qual è il prezzo medio per i prodotti di colore rosso o nero?
# - Qual è il prezzo massimo per i prodotti di taglia 42 e peso oltre i 10 Kg?
# - Qual è il nome inglese e il costo di produzione (StandardCost) di tutti i prodotti di taglia 42, peso oltre i 10 Kg e colore argento?
# - Visualizziamo lo StandardCost e il DealerPrice degli ultimi 20 elementi del dataset: quali sono le differenze? C'è un pattern? C'è qualche elemento che non lo segue?

# %%
import os

import dotenv
import pandas as pd
import sqlalchemy

dotenv.load_dotenv(dotenv_path="credenziali.env", override=True)

username = os.getenv("username")
password = os.getenv("password")
host = os.getenv("host")
dbname = os.getenv("dbname")

connection_string = (
    "mysql+pymysql://" + username + ":" + password + "@" + host + "/" + dbname
)
print(connection_string)

db_engine = sqlalchemy.create_engine(connection_string)
# Out:
# mysql+pymysql://studente_dapt:Ep1c0d3!!D4t4**4n4lys1s@epicode-data-pt-mysql.cvetyjye2qbl.eu-central-1.rds.amazonaws.com/AdventureWorksDW

# %%
query = "SELECT * FROM dimproduct"
dp = pd.read_sql(query, db_engine)
dp
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0             1             AR-5381                    NaN
# 1             2             BA-8327                    NaN
# 2             3             BE-2349                    NaN
# 3             4             BE-2908                    NaN
# 4             5             BL-2036                    NaN
# ..          ...                 ...                    ...
# 601         602             BB-8107                    5.0
# 602         603             BB-9108                    5.0
# 603         604          BK-R19B-44                    2.0
# 604         605          BK-R19B-48                    2.0
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode     EnglishProductName  \
# 0                    None                None        Adjustable Race
# 1                    None                None           Bearing Ball
# ...

# %%
dp.shape
# Out:
# (606, 36)

# %%
dp.columns
# Out:
# Index(['ProductKey', 'ProductAlternateKey', 'ProductSubcategoryKey',
#        'WeightUnitMeasureCode', 'SizeUnitMeasureCode', 'EnglishProductName',
#        'SpanishProductName', 'FrenchProductName', 'StandardCost',
#        'FinishedGoodsFlag', 'Color', 'SafetyStockLevel', 'ReorderPoint',
#        'ListPrice', 'Size', 'SizeRange', 'Weight', 'DaysToManufacture',
#        'ProductLine', 'DealerPrice', 'Class', 'Style', 'ModelName',
#        'LargePhoto', 'EnglishDescription', 'FrenchDescription',
#        'ChineseDescription', 'ArabicDescription', 'HebrewDescription',
#        'ThaiDescription', 'GermanDescription', 'JapaneseDescription',
#        'TurkishDescription', 'StartDate', 'EndDate', 'Status'],
#       dtype='object')

# %%
dp.head(1)
# Out:
#    ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0           1             AR-5381                    NaN
#
#   WeightUnitMeasureCode SizeUnitMeasureCode EnglishProductName  \
# 0                  None                None    Adjustable Race
#
#   SpanishProductName FrenchProductName  StandardCost  FinishedGoodsFlag  ...  \
# 0                                                NaN                  0  ...
#
#   ChineseDescription  ArabicDescription  HebrewDescription  ThaiDescription  \
# 0               None               None               None             None
#
#   GermanDescription JapaneseDescription  TurkishDescription  StartDate  \
# 0              None                None                None 2003-07-01
#
#   EndDate   Status
# 0     NaT  Current
#
# [1 rows x 36 columns]

# %%
dp.tail(1)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode  EnglishProductName  \
# 605                    LB                  CM  Road-750 Black, 52
#
#             SpanishProductName           FrenchProductName  StandardCost  \
# 605  Carretera: 750, negra, 52  Vélo de route 750 noir, 52        343.65
#
#      FinishedGoodsFlag  ...                 ChineseDescription  \
# 605                  1  ...  入门级成人自行车；确保越野旅行或公路骑乘的舒适。快拆式车毂和轮缘。
#
#                                      ArabicDescription  \
# 605  إنها دراجة مناسبة للمبتدئين من البالغين؛ فهي ت...
#
#                                      HebrewDescription  \
# 605  אופני מבוגרים למתחילים; מציעים רכיבה נוחה "מחו...
#
#                                        ThaiDescription  \
# 605  จักรยานระดับเริ่มต้นสำหรับผู้ใหญ่ ให้ความสบายใ...
#
#                                      GermanDescription  \
# ...

# %%
dp.sample(5)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 502         503          FR-T67U-54                   16.0
# 577         578          BK-T44U-50                    3.0
# 160         161             MS-0253                    NaN
# 418         419             RW-M423                   17.0
# 353         354          BK-M68S-42                    1.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode           EnglishProductName  \
# 502                    LB                  CM  LL Touring Frame - Blue, 54
# 577                    LB                  CM        Touring-2000 Blue, 50
# 160                  None                None                Metal Sheet 2
# 418                  None                None       LL Mountain Rear Wheel
# 353                    LB                  CM      Mountain-200 Silver, 42
#
#                SpanishProductName                         FrenchProductName  \
# 502  Cuadro de paseo GB: azul, 54  Cadre de vélo de randonnée LL - bleu, 54
# ...

# %%
dp["Color"].unique()
# Out:
# array(['NA', 'Black', 'Silver', 'Red', 'White', 'Blue', 'Multi', 'Yellow',
#        'Grey', 'Silver/Black'], dtype=object)

# %%
dp["Weight"].mean()
# Out:
# np.float64(56.1932269503546)

# %%
dp["Weight"].min()
# Out:
# 2.12

# %%
dp["Weight"].max()
# Out:
# 1050.0

# %%
dp["Weight"].describe()
# Out:
# count     282.000000
# mean       56.193227
# std       158.000652
# min         2.120000
# 25%         2.680000
# 50%        15.420000
# 75%        24.130000
# max      1050.000000
# Name: Weight, dtype: float64

# %%
filtro = dp["Weight"] > 100
dp.loc[filtro].shape # I prodotti che pesano più di 100 sono 18
# Out:
# (28, 36)

# %%
dp["DealerPrice"].describe()
# Out:
# count     395.000000
# mean      448.597060
# std       503.225071
# min         1.374000
# 25%        41.994000
# 50%       218.454000
# 75%       722.594900
# max      2146.962000
# Name: DealerPrice, dtype: float64

# %%
filtro = dp["Color"] == "Blue"
dp.loc[filtro, "DealerPrice"].mean()
# Out:
# np.float64(516.0631785714286)

# %%
dp.groupby("Color")["DealerPrice"].mean()
# Out:
# Color
# Black           474.823688
# Blue            516.063179
# Grey             75.000000
# Multi            29.358233
# NA               33.882386
# Red             705.963284
# Silver          668.156360
# Silver/Black     38.411143
# White             5.547000
# Yellow          550.868478
# Name: DealerPrice, dtype: float64

# %%
filtro_red = dp["Color"] == "Red"
filtro_black = dp["Color"] == "Black"
filtro = filtro_red | filtro_black
dp.loc[filtro, "DealerPrice"].mean().round()
# Out:
# np.float64(550.0)

# %%
dp.columns
# Out:
# Index(['ProductKey', 'ProductAlternateKey', 'ProductSubcategoryKey',
#        'WeightUnitMeasureCode', 'SizeUnitMeasureCode', 'EnglishProductName',
#        'SpanishProductName', 'FrenchProductName', 'StandardCost',
#        'FinishedGoodsFlag', 'Color', 'SafetyStockLevel', 'ReorderPoint',
#        'ListPrice', 'Size', 'SizeRange', 'Weight', 'DaysToManufacture',
#        'ProductLine', 'DealerPrice', 'Class', 'Style', 'ModelName',
#        'LargePhoto', 'EnglishDescription', 'FrenchDescription',
#        'ChineseDescription', 'ArabicDescription', 'HebrewDescription',
#        'ThaiDescription', 'GermanDescription', 'JapaneseDescription',
#        'TurkishDescription', 'StartDate', 'EndDate', 'Status'],
#       dtype='object')

# %%
filtro_tg = dp["Size"] == "42"
filtro_weight = dp["Weight"] > 10
filtro = filtro_tg & filtro_weight
dp.loc[filtro, "DealerPrice"].max()
# Out:
# 2039.994

# %%
dp["Color"].unique()
# Out:
# array(['NA', 'Black', 'Silver', 'Red', 'White', 'Blue', 'Multi', 'Yellow',
#        'Grey', 'Silver/Black'], dtype=object)

# %%
filtro_tg = dp["Size"] == "42"
filtro_weight = dp["Weight"] > 10
filtro_color= dp["Color"] == "Silver"
filtro = filtro_tg & filtro_weight & filtro_color
dp.loc[filtro, ["EnglishProductName" , "StandardCost"]]
# Out:
#             EnglishProductName  StandardCost
# 344    Mountain-100 Silver, 42       1912.15
# 353    Mountain-200 Silver, 42       1117.86
# 354    Mountain-200 Silver, 42       1265.62
# 588  Mountain-400-W Silver, 42        419.78
# 591    Mountain-500 Silver, 42        308.22

# %%
dp["DealerPrice"].tail(20)
# Out:
# 586    461.694
# 587    461.694
# 588    461.694
# 589    461.694
# 590    338.994
# 591    338.994
# 592    338.994
# 593    338.994
# 594    338.994
# 595    323.994
# 596    323.994
# 597    323.994
# 598    323.994
# 599    323.994
# 600     32.394
# 601     60.744
# 602     72.894
# 603    323.994
# 604    323.994
# 605    323.994
# Name: DealerPrice, dtype: float64

# %%
last20 = dp.tail(20)
last20.loc[:, ["DealerPrice", "StandardCost"]] # Noto che negli ultimi 3 items il DP < SC, che non è il massimo
# Out:
#      DealerPrice  StandardCost
# 586      461.694        419.78
# 587      461.694        419.78
# 588      461.694        419.78
# 589      461.694        419.78
# 590      338.994        308.22
# 591      338.994        308.22
# 592      338.994        308.22
# 593      338.994        308.22
# 594      338.994        308.22
# 595      323.994        294.58
# 596      323.994        294.58
# 597      323.994        294.58
# 598      323.994        294.58
# 599      323.994        294.58
# 600       32.394         23.97
# 601       60.744         44.95
# 602       72.894         53.94
# 603      323.994        343.65
# 604      323.994        343.65
# 605      323.994        343.65

# %% [markdown]
# ## ESERCIZIO 2
#
# Dai dataset in piattaforma, carichiamo il file con i dati dei pub, circoli e locali in Italia, chiamato *Mappa-dei-pub-circoli-locali-in-Italia.csv*
# Nota: il dataset non ha un encoding UTF-8 ma Latin1;
# inoltre il separatore non è una virgola, ma un punto e virgola.
# Dunque per leggerlo dovremo aggiungere i parametri encoding= e sep=,
# ad esempio: pd.read_csv(file_path, encoding="latin1", sep=";") dove file_path è la posizione del file nel nostro calcolatore.
#
# Esaminiamo il dataset:
# - quante attività ci sono nel quadrato di longitudine 9-10 e latitudine 45-46?
# - quante attività ci sono nella provincia di Vicenza?
# - quante attività ci sono in Lazio e Abruzzo assieme?

# %%
file_path = "../altri_dataset/Mappa-dei-pub-circoli-locali-in-Italia.csv"
pub = pd.read_csv(file_path, encoding="latin1", sep=";") 
pub
# Out:
#             Comune                       Provincia   Regione             Nome  \
# 0            ALTRO                           ALTRO     ALTRO              NaN
# 1            ALTRO                           ALTRO     ALTRO      Lenny's Pub
# 2            ALTRO                           ALTRO     ALTRO  Murrayfield Pub
# 3            ALTRO                           ALTRO     ALTRO           Snop?e
# 4     ALA DI STURA  CITTA' METROPOLITANA DI TORINO  Piemonte              NaN
# ...            ...                             ...       ...              ...
# 2630      BARLETTA           BARLETTA-ANDRIA-TRANI    Puglia      Santa Croce
# 2631     BISCEGLIE           BARLETTA-ANDRIA-TRANI    Puglia      Auld Dublin
# 2632     BISCEGLIE           BARLETTA-ANDRIA-TRANI    Puglia            Ferus
# 2633         TRANI           BARLETTA-ANDRIA-TRANI    Puglia          Re Artù
# 2634         TRANI           BARLETTA-ANDRIA-TRANI    Puglia     Well's Fargo
#
# ...

# %%
pub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2635 entries, 0 to 2634
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Comune                           2635 non-null   object
#  1   Provincia                        2635 non-null   object
#  2   Regione                          2635 non-null   object
#  3   Nome                             2337 non-null   object
#  4   Anno inserimento                 2635 non-null   int64
#  5   Data e ora inserimento           2635 non-null   object
#  6   Identificatore in OpenStreetMap  2635 non-null   int64
#  7   Longitudine                      2635 non-null   float64
#  8   Latitudine                       2635 non-null   float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 185.4+ KB

# %%
filtro_long = (pub["Longitudine"] > 9) & (pub["Longitudine"] < 10)
filtro_lat = (pub["Latitudine"] > 45) & (pub["Latitudine"] < 46)
filtro = filtro_long & filtro_lat

# %%
attivita = pub.loc[filtro, "Nome"]

# %%
attivita.shape
# Out:
# (306,)

# %%
pub["Provincia"].unique()
# Out:
# array(['ALTRO', "CITTA' METROPOLITANA DI TORINO", 'VERCELLI', 'NOVARA',
#        'CUNEO', 'ASTI', 'ALESSANDRIA', 'AOSTA', 'IMPERIA', 'SAVONA',
#        "CITTA' METROPOLITANA DI GENOVA", 'LA SPEZIA', 'VARESE', 'COMO',
#        'SONDRIO', "CITTA' METROPOLITANA DI MILANO", 'BERGAMO', 'BRESCIA',
#        'PAVIA', 'CREMONA', 'MANTOVA', 'BOLZANO', 'TRENTO', 'VERONA',
#        'VICENZA', 'BELLUNO', 'TREVISO', "CITTA' METROPOLITANA DI VENEZIA",
#        'PADOVA', 'ROVIGO', 'UDINE', 'GORIZIA', 'TRIESTE', 'PIACENZA',
#        'PARMA', 'REGGIO EMILIA', 'MODENA',
#        "CITTA' METROPOLITANA DI BOLOGNA", 'FERRARA', 'RAVENNA', "FORLI'",
#        'PESARO E URBINO', 'ANCONA', 'MACERATA', 'ASCOLI PICENO',
#        'MASSA-CARRARA', 'LUCCA', 'PISTOIA',
#        "CITTA' METROPOLITANA DI FIRENZE", 'LIVORNO', 'PISA', 'AREZZO',
#        'SIENA', 'GROSSETO', 'PERUGIA', 'TERNI', 'VITERBO', 'RIETI',
#        "CITTA' METROPOLITANA DI ROMA CAPITALE", 'LATINA', 'FROSINONE',
# ...

# %%
provincia = pub["Provincia"] == "VARESE"

# %%
pub.loc[provincia, "Nome"].shape
# Out:
# (65,)

# %%
pub["Regione"].unique()
# Out:
# array(['ALTRO', 'Piemonte', "Valle d'Aosta", 'Liguria', 'Lombardia',
#        'Trentino-Alto Adige', 'Veneto', 'Friuli-Venezia Giulia',
#        'Emilia-Romagna', 'Marche', 'Toscana', 'Umbria', 'Lazio',
#        'Campania', 'Abruzzo', 'Molise', 'Puglia', 'Basilicata',
#        'Calabria', 'Sicilia', 'Sardegna'], dtype=object)

# %%
Reg_Laz = pub["Regione"] == "Lazio"
Reg_Abr = pub["Regione"] == "Abruzzo"

# %%
filtro = Reg_Laz | Reg_Abr

# %%
pub.loc[filtro, "Nome"].shape
# Out:
# (337,)

# %% [markdown]
# ## ESERCIZIO 7
#
# Abbiamo un DataFrame di dipendenti:
# employees_df = pd.DataFrame({ 'employee_id': [101, 102, 103, 104, 105],
#                             'name': ['Alice', 'Bob', 'Charlie', 'David', 'Emma'],
#                             'department_id': [1, 2, 1, 2, 3] })
#
# E un DataFrame di dipartimenti:
# departments_df = pd.DataFrame({ 'department_id': [1, 2, 3],
#                                 'department_name': ['HR', 'IT', 'Finance'],
#                                 'location': ['New York', 'San Francisco', 'Chicago'] })
#
# Unire questi DataFrame in base alla colonna comune department_id, in modo da avere nel risultato informazioni sia sui dipendenti che sui dipartimenti, usando la funzione *.merge()*
# - Per ogni DataFrame, trasformare la colonna department_id nell'indice, facendo in modo che la modifica sia permanente;
# - poi unire i due dataset mediante il metodo .join()
#
# Ci sono differenze nel risultato? Quali? Perché?

# %%
employees_df = pd.DataFrame({ 'employee_id': [101, 102, 103, 104, 105],
'name': ['Alice', 'Bob', 'Charlie', 'David', 'Emma'],
'department_id': [1, 2, 1, 2, 3] })

departments_df = pd.DataFrame({ 'department_id': [1, 2, 3],
'department_name': ['HR', 'IT', 'Finance'],
'location': ['New York', 'San Francisco', 'Chicago'] })

# %%
employees_df
# Out:
#    employee_id     name  department_id
# 0          101    Alice              1
# 1          102      Bob              2
# 2          103  Charlie              1
# 3          104    David              2
# 4          105     Emma              3

# %%
departments_df
# Out:
#    department_id department_name       location
# 0              1              HR       New York
# 1              2              IT  San Francisco
# 2              3         Finance        Chicago

# %%
pd.merge(
    left=employees_df,
    right=departments_df,
    left_on="department_id",
    right_on="department_id",
    how="inner"
)
# Out:
#    employee_id     name  department_id department_name       location
# 0          101    Alice              1              HR       New York
# 1          102      Bob              2              IT  San Francisco
# 2          103  Charlie              1              HR       New York
# 3          104    David              2              IT  San Francisco
# 4          105     Emma              3         Finance        Chicago

# %%
joindf = pd.merge(
    left=employees_df,
    right=departments_df,
    left_on="department_id",
    right_index=True,
    how="inner"
)

# %%
joindf
# Out:
#    department_id  employee_id     name  department_id_x  department_id_y  \
# 0              1          101    Alice                1                2
# 1              2          102      Bob                2                3
# 2              1          103  Charlie                1                2
# 3              2          104    David                2                3
#
#   department_name       location
# 0              IT  San Francisco
# 1         Finance        Chicago
# 2              IT  San Francisco
# 3         Finance        Chicago
