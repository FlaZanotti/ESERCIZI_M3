# %% [markdown]
# ## ESERCIZIO 1
#
# Tra i beginner datasets scaricabili all'indirizzo https://www.kaggle.com/datasets/ahmettezcantekin/beginner-datasets
# selezioniamo *amazon.csv*, un dataset contenente una serie di recensioni su Amazon:
# - Valutiamo la dimensione del dataset
# - Osserviamo quali sono i nomi di colonna
# - Visualizziamo dieci righe a caso
# - Il dataset è bilanciato, ovvero: il numero di recensioni positive è uguale a quello delle negative, oppure no?

# %%
import pandas as pd

# %%
file_path = "beginner_datasets/amazon.csv"

# %%
dataset_amz = pd.read_csv(file_path)

# %%
dataset_amz
# Out:
#                                               reviewText  Positive
# 0      This is a one of the best apps acording to a b...         1
# 1      This is a pretty good version of the game for ...         1
# 2      this is a really cool game. there are a bunch ...         1
# 3      This is a silly game and can be frustrating, b...         1
# 4      This is a terrific game on any pad. Hrs of fun...         1
# ...                                                  ...       ...
# 19995  this app is fricken stupid.it froze on the kin...         0
# 19996  Please add me!!!!! I need neighbors! Ginger101...         1
# 19997  love it!  this game. is awesome. wish it had m...         1
# 19998  I love love love this app on my side of fashio...         1
# 19999  This game is a rip off. Here is a list of thin...         0
#
# [20000 rows x 2 columns]

# %%
    dataset_amz.shape # le dimensioni sono 20000x2
# Out:
# (20000, 2)

# %%
dataset_amz.columns
# Out:
# Index(['reviewText', 'Positive'], dtype='object')

# %%
dataset_amz.sample(5) # Valuto 5 righe casuali
# Out:
#                                               reviewText  Positive
# 2912   welll I never played this game but seems reall...         0
# 12307  Especially with the latest updates. I use the ...         1
# 4333   app is as advertrised. it is simple to use and...         1
# 12164  Love this alarm clock app.. love the different...         1
# 10102  As a professional writer, i look for writing a...         1

# %%
dataset_amz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   reviewText  20000 non-null  object
#  1   Positive    20000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 312.6+ KB

# %%
dataset_amz["Positive"].value_counts() # il dataset non è bilanciato perchè ho un rapporto 3:1 fra recensioni posite e negative
# Out:
# Positive
# 1    15233
# 0     4767
# Name: count, dtype: int64

# %% [markdown]
# ## ESERCIZIO 2
#
# Il dataset diabetes.csv raccoglie persone con diabete o meno, e il valore di diverse variabili fisiologiche dei pazienti.
# - Osserviamone le dimensioni e un'anteprima di cinque righe;
# - Prendiamoci un po' di tempo per dare un'occhiata ai metadati delle colonne;
# - Stampiamo dei descrittori statistici del dataset;
# - Selezioniamo i dati relativi a diverse fasce di età: 20-29, 30-39, 40-50;
# - Qual è la media della pressione sanguigna diastolica per le diverse fasce di età?

# %%
import pandas as pd

# %%
file_path = "beginner_datasets/diabetes.csv"

# %%
df_diab = pd.read_csv(file_path)

# %%
df_diab.shape # dimensioni del df
# Out:
# (768, 9)

# %%
df_diab.head(5) # anteprima prime 5 righe
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %%
df_diab.columns
# Out:
# Index(['Number of times pregnant',
#        'Plasma glucose concentration a 2 hours in an oral glucose tolerance test',
#        'Diastolic blood pressure (mm Hg)', 'Triceps skin fold thickness (mm)',
#        '2-Hour serum insulin (mu U/ml)',
#        'Body mass index (weight in kg/(height in m)^2)',
#        'Diabetes pedigree function', 'Age (years)', 'Class variable'],
#       dtype='object')

# %%
df_diab.info() # check sui metadati che NON contengono valori nulli
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Number of times pregnant                                                  768 non-null    int64
#  1   Plasma glucose concentration a 2 hours in an oral glucose tolerance test  768 non-null    int64
#  2   Diastolic blood pressure (mm Hg)                                          768 non-null    int64
#  3   Triceps skin fold thickness (mm)                                          768 non-null    int64
#  4   2-Hour serum insulin (mu U/ml)                                            768 non-null    int64
#  5   Body mass index (weight in kg/(height in m)^2)                            768 non-null    float64
# ...

# %%
df_diab.describe() # anteprima descrittori statistici del df
# Out:
#        Number of times pregnant  \
# count                768.000000
# mean                   3.845052
# std                    3.369578
# min                    0.000000
# 25%                    1.000000
# 50%                    3.000000
# 75%                    6.000000
# max                   17.000000
#
#        Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# count                                         768.000000
# mean                                          120.894531
# std                                            31.972618
# min                                             0.000000
# 25%                                            99.000000
# 50%                                           117.000000
# 75%                                           140.250000
# max                                           199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# ...

# %%
FILTRO_1 = ((df_diab["Age (years)"]) >= 20) & ((df_diab["Age (years)"]) < 30)

# %%
df_diab.loc[FILTRO_1]
# Out:
#      Number of times pregnant  \
# 3                           1
# 6                           3
# 7                          10
# 20                          3
# 23                          9
# ..                        ...
# 753                         0
# 758                         1
# 760                         2
# 764                         2
# 767                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 3                                                   89
# 6                                                   78
# 7                                                  115
# 20                                                 126
# 23                                                 119
# ..                                                 ...
# 753                                                181
# 758                                                106
# 760                                                 88
# ...

# %%
FILTRO_2 = ((df_diab["Age (years)"]) >= 30) & ((df_diab["Age (years)"]) < 40)

# %%
df_diab.loc[FILTRO_2]
# Out:
#      Number of times pregnant  \
# 1                           1
# 2                           8
# 4                           0
# 5                           5
# 10                          4
# ..                        ...
# 748                         3
# 755                         1
# 756                         7
# 762                         9
# 765                         5
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 1                                                   85
# 2                                                  183
# 4                                                  137
# 5                                                  116
# 10                                                 110
# ..                                                 ...
# 748                                                187
# 755                                                128
# 756                                                137
# ...

# %%
FILTRO_3 = ((df_diab["Age (years)"]) >= 40) & ((df_diab["Age (years)"]) < 50)

# %%
df_diab.loc[FILTRO_3]
# Out:
#      Number of times pregnant  \
# 22                          7
# 25                         10
# 26                          7
# 34                         10
# 37                          9
# ..                        ...
# 743                         9
# 745                        12
# 754                         8
# 761                         9
# 766                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 22                                                 196
# 25                                                 125
# 26                                                 147
# 34                                                 122
# 37                                                 102
# ..                                                 ...
# 743                                                140
# 745                                                100
# 754                                                154
# ...

# %%
df_diab_20_29 = df_diab.loc[FILTRO_1]

# %%
df_diab_30_39 = df_diab.loc[FILTRO_2]

# %%
df_diab_40_49 = df_diab.loc[FILTRO_3]

# %%
df_diab_20_29["Diastolic blood pressure (mm Hg)"].mean()
# Out:
# np.float64(65.34848484848484)

# %%
df_diab_30_39["Diastolic blood pressure (mm Hg)"].mean()
# Out:
# np.float64(69.66666666666667)

# %%
df_diab_40_49["Diastolic blood pressure (mm Hg)"].mean()
# Out:
# np.float64(73.94067796610169)

# %% [markdown]
# ## ESERCIZIO 3
#
# Esercizio Il dataset *insurance.csv* contiene dati rispetto a caratteristiche e abitudini delle persone, e della zona in cui vivono, rispetto ai costi individuali per le cure mediche come premio per le assicurazioni sulla salute.
# - Visualizziamone le dimensioni, un'anteprima, e osserviamo i nomi di colonna;
# - Quali sono le medie di charges rispetto a region? Ci sono differenze significative?
# - E rispetto a smoker? E a sex?
# - Quali sono i descrittori statistici di bmi? Quali sono minimo, media e massimo di charges rispetto ai diversi quartili dei valori di bmi?

# %%
file_path = "beginner_datasets/insurance.csv"

# %%
df_ins = pd.read_csv(file_path)

# %%
df_ins
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df_ins.shape
# Out:
# (1338, 7)

# %%
df_ins
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df_ins.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df_ins.nunique()
# Out:
# age           47
# sex            2
# bmi          548
# children       6
# smoker         2
# region         4
# charges     1337
# dtype: int64

# %%
df_ins["region"].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
FILTRO_SW = df_ins["region"] == "southwest"

# %%
df_ins.loc[FILTRO_SW]
# Out:
#       age     sex   bmi  children smoker     region      charges
# 0      19  female  27.9         0    yes  southwest  16884.92400
# 12     23    male  34.4         0     no  southwest   1826.84300
# 15     19    male  24.6         1     no  southwest   1837.23700
# 18     56    male  40.3         0     no  southwest  10602.38500
# 19     30    male  35.3         0    yes  southwest  36837.46700
# ...   ...     ...   ...       ...    ...        ...          ...
# 1316   19  female  20.6         0     no  southwest   1731.67700
# 1329   52    male  38.6         2     no  southwest  10325.20600
# 1331   23  female  33.4         0     no  southwest  10795.93733
# 1332   52  female  44.7         3     no  southwest  11411.68500
# 1336   21  female  25.8         0     no  southwest   2007.94500
#
# [325 rows x 7 columns]

# %%
df_sw = df_ins.loc[FILTRO_SW]

# %%
df_sw["charges"].mean()
# Out:
# np.float64(12346.937377292308)

# %%
FILTRO_SE = df_ins["region"] == "southest"

# %%
df_se = df_ins.loc[FILTRO_SE]

# %%
df_se["charges"].mean()
# Out:
# nan

# %%
FILTRO_NE = df_ins["region"] == "northeast"

# %%
df_ne = df_ins.loc[FILTRO_NE]

# %%
df_ne["charges"].mean()
# Out:
# np.float64(13406.384516385804)

# %%
FILTRO_NW = df_ins["region"] == "northwest"

# %%
df_nw = df_ins.loc[FILTRO_NW]

# %%
df_nw["charges"].mean()
# Out:
# np.float64(12417.57537396923)

# %%
df_ins["smoker"]
# Out:
# 0       yes
# 1        no
# 2        no
# 3        no
# 4        no
#        ...
# 1333     no
# 1334     no
# 1335     no
# 1336     no
# 1337    yes
# Name: smoker, Length: 1338, dtype: object

# %%
filtro = df_ins["smoker"] == "yes"

# %%
df_ins.loc[filtro, "charges"].mean()
# Out:
# np.float64(32050.23183153284)

# %%
filtro = df_ins["smoker"] == "no"
df_ins.loc[filtro, "charges"].mean()
# Out:
# np.float64(8434.268297856204)

# %%
df_ins["sex"].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
filtro = df_ins["sex"] == "male"
df_ins.loc[filtro, "charges"].mean()
# Out:
# np.float64(13956.751177721893)

# %%
filtro = df_ins["sex"] == "female"
df_ins.loc[filtro, "charges"].mean()
# Out:
# np.float64(12569.578843835347)

# %%
df_ins.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df_ins["bmi"].describe()
# Out:
# count    1338.000000
# mean       30.663397
# std         6.098187
# min        15.960000
# 25%        26.296250
# 50%        30.400000
# 75%        34.693750
# max        53.130000
# Name: bmi, dtype: float64

# %%
filtro1 = df_ins["bmi"] >= 15.96
filtro2 = df_ins["bmi"] <= 26.29625
filtro = filtro1 & filtro2

# %%
df_ins.loc[filtro, "charges"].min()
# Out:
# 1121.8739

# %%
df_ins.loc[filtro, "charges"].max()
# Out:
# 38245.59327

# %%
df_ins.loc[filtro, "charges"].mean() #posso ripetere lo stesso procedimento per il 2°,3° e 4° quartile
# Out:
# np.float64(10360.662825492538)

# %% [markdown]
# ## ESERCIZIO 4
#
# Il dataset *pokemon.csv* contiene un database di Pokémon, con dati quali nome, tipi di attacco, valori di attacco/difesa/eccetera, e se sono o meno leggendari.
# - Verifichiamo la dimensione, un'anteprima e osserviamo i nomi di colonna;
# - È verosimile che la prima colonna dovrebbe essere un indice? *Si, è l'indice del Pokèdex*
# - Confrontiamolo con l'indice messo automaticamente da Pandas: combaciano? *non combaciano perchè la prima colonna si riferisce al n° di pokèdex del pokèmon che, nel caso delle Mega (ad es.), si ripete. Non è una PK come l'indice default di Pandas*
# - Se no, settare la prima colonna come indice.
#
# - Quali sono i Pokémon leggendari?
# - E quali sono i leggendari di tipo 1 Grass?
# - E leggendari di tipo 1 Ice o Fire?
# - Trasformiamo la colonna Name nell'indice;
# - Quali sono i Pokémon della prima generazione con attacco > 50 e HP < 60?

# %%
file_path = "beginner_datasets/pokemon.csv"

# %%
poke = pd.read_csv(file_path)
poke
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
poke.shape
# Out:
# (800, 13)

# %%
poke = poke.set_index("#")

# %%
poke
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
filtro_leg = poke["Legendary"] == True
leggendari = poke.loc[filtro_leg]
leggendari
# Out:
#                     Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# #
# 144             Articuno       Ice    Flying    580   90      85      100
# 145               Zapdos  Electric    Flying    580   90      90       85
# 146              Moltres      Fire    Flying    580   90     100       90
# 150               Mewtwo   Psychic       NaN    680  106     110       90
# 150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
# ..                   ...       ...       ...    ...  ...     ...      ...
# 719              Diancie      Rock     Fairy    600   50     100      150
# 719  DiancieMega Diancie      Rock     Fairy    700   50     160      110
# 720  HoopaHoopa Confined   Psychic     Ghost    600   80     110       60
# 720   HoopaHoopa Unbound   Psychic      Dark    680   80     160       60
# 721            Volcanion      Fire     Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
filtro_leg = poke["Legendary"] == True
leggendari = poke.loc[filtro_leg]
filtro_grass = poke["Type 1"] == "Grass"
filtro = filtro_leg & filtro_grass
poke.loc[filtro]
# Out:
#                   Name Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 492  ShayminLand Forme  Grass       NaN    600  100     100      100      100
# 492   ShayminSky Forme  Grass    Flying    600  100     103       75      120
# 640           Virizion  Grass  Fighting    580   91      90       72       90
#
#      Sp. Def  Speed  Generation  Legendary
# #
# 492      100    100           4       True
# 492       75    127           4       True
# 640      129    108           5       True

# %%
filtro_leg = poke["Legendary"] == True
leggendari = poke.loc[filtro_leg]
filtro_ice = poke["Type 1"] == "Ice"
filtro_fire = poke["Type 1"] == "Fire"
filtro = filtro_leg & (filtro_ice | filtro_fire)
poke.loc[filtro]
# Out:
#           Name Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 144   Articuno    Ice  Flying    580   90      85      100       95      125
# 146    Moltres   Fire  Flying    580   90     100       90      125       85
# 244      Entei   Fire     NaN    580  115     115       85       90       75
# 250      Ho-oh   Fire  Flying    680  106     130       90      110      154
# 378     Regice    Ice     NaN    580   80      50      100      100      200
# 485    Heatran   Fire   Steel    600   91      90      106      130      106
# 721  Volcanion   Fire   Water    600   80     110      120      130       90
#
#      Speed  Generation  Legendary
# #
# 144     85           1       True
# 146     90           1       True
# 244    100           2       True
# 250     90           2       True
# 378     50           3       True
# 485     77           4       True
# 721     70           6       True

# %%
poke_N = poke.set_index("Name")

# %%
poke_N
# Out:
#                         Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur                Grass  Poison    318  45      49       49       65
# Ivysaur                  Grass  Poison    405  60      62       63       80
# Venusaur                 Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur    Grass  Poison    625  80     100      123      122
# Charmander                Fire     NaN    309  39      52       43       60
# ...                        ...     ...    ...  ..     ...      ...      ...
# Diancie                   Rock   Fairy    600  50     100      150      100
# DiancieMega Diancie       Rock   Fairy    700  50     160      110      160
# HoopaHoopa Confined    Psychic   Ghost    600  80     110       60      150
# HoopaHoopa Unbound     Psychic    Dark    680  80     160       60      170
# Volcanion                 Fire   Water    600  80     110      120      130
#
# ...

# %%
filtro_gen = poke["Generation"] == 1
filtro_hp = poke["HP"] < 60
filtro_at = poke["Attack"] > 50
filtro = filtro_gen & filtro_hp & filtro_at

# %%
poke.loc[filtro]
# Out:
#            Name    Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 4    Charmander      Fire     NaN    309  39      52       43       60
# 5    Charmeleon      Fire     NaN    405  58      64       58       80
# 8     Wartortle     Water     NaN    405  59      63       80       65
# 19      Rattata    Normal     NaN    253  30      56       35       25
# 20     Raticate    Normal     NaN    413  55      81       60       50
# 21      Spearow    Normal  Flying    262  40      60       30       31
# 23        Ekans    Poison     NaN    288  35      60       44       40
# 25      Pikachu  Electric     NaN    320  35      55       40       50
# 27    Sandshrew    Ground     NaN    300  50      75       85       20
# 32     Nidoran♂    Poison     NaN    273  46      57       40       40
# 46        Paras       Bug   Grass    285  35      70       55       45
# 50      Diglett    Ground     NaN    265  10      55       25       35
# ...

# %% [markdown]
# ## ESERCIZIO 5
#
# Dai dataset in piattaforma, carichiamo il file con i dati dei pub, circoli e locali in Italia, chiamato *Mappa-dei-pub-circoli-locali-in-Italia.csv*
# Nota: il dataset non ha un encoding UTF-8 ma Latin1;
# inoltre il separatore non è una virgola, ma un punto e virgola.
# Dunque per leggerlo dovremo aggiungere i parametri *encoding=* e *sep=*,
# ad esempio: pd.read_csv(file_path, encoding="latin1", sep=";") dove file_path è la posizione del file nel nostro calcolatore.
# Esaminiamo il dataset:
# - quanti dati ci sono in totale?
# - quali sono i metadati?
# - stampiamo il primo elemento
# - stampiamo l'ultimo elemento
# - riusciamo a stampare un elemento a caso?
# - quali sono gli anni di inserimento presenti?
# - quante enoteche ci sono, e come si chiamano?
#
#
# L’ultimo punto potrebbe richiedere molti passaggi, perché i dati in questo dataset non hanno subìto un processo di pulizia e trasformazione adeguato!

# %%
file_path = "altri_dataset/Mappa-dei-pub-circoli-locali-in-Italia.csv"

# %%
pub = pd.read_csv(file_path, encoding="latin1", sep=";")

# %%
pub
# Out:
#             Comune                       Provincia   Regione             Nome  \
# 0            ALTRO                           ALTRO     ALTRO              NaN
# 1            ALTRO                           ALTRO     ALTRO      Lenny's Pub
# 2            ALTRO                           ALTRO     ALTRO  Murrayfield Pub
# 3            ALTRO                           ALTRO     ALTRO           Snop?e
# 4     ALA DI STURA  CITTA' METROPOLITANA DI TORINO  Piemonte              NaN
# ...            ...                             ...       ...              ...
# 2630      BARLETTA           BARLETTA-ANDRIA-TRANI    Puglia      Santa Croce
# 2631     BISCEGLIE           BARLETTA-ANDRIA-TRANI    Puglia      Auld Dublin
# 2632     BISCEGLIE           BARLETTA-ANDRIA-TRANI    Puglia            Ferus
# 2633         TRANI           BARLETTA-ANDRIA-TRANI    Puglia          Re Artù
# 2634         TRANI           BARLETTA-ANDRIA-TRANI    Puglia     Well's Fargo
#
# ...

# %%
pub.columns
# Out:
# Index(['Comune', 'Provincia', 'Regione', 'Nome', 'Anno inserimento',
#        'Data e ora inserimento', 'Identificatore in OpenStreetMap',
#        'Longitudine', 'Latitudine'],
#       dtype='object')

# %%
pub.head(1)
# Out:
#   Comune Provincia Regione Nome  Anno inserimento Data e ora inserimento  \
# 0  ALTRO     ALTRO   ALTRO  NaN              2011   2011-06-25T23:17:43Z
#
#    Identificatore in OpenStreetMap  Longitudine  Latitudine
# 0                       1339088150    13.733257    45.57583

# %%
pub.tail(1)
# Out:
#      Comune              Provincia Regione          Nome  Anno inserimento  \
# 2634  TRANI  BARLETTA-ANDRIA-TRANI  Puglia  Well's Fargo              2009
#
#      Data e ora inserimento  Identificatore in OpenStreetMap  Longitudine  \
# 2634   2009-08-10T12:44:03Z                        387223648    16.436765
#
#       Latitudine
# 2634   41.267264

# %%
pub.sample(1)
# Out:
#                   Comune Provincia  Regione             Nome  \
# 1720  SAN GIULIANO TERME      PISA  Toscana  Sali Scendi Pub
#
#       Anno inserimento Data e ora inserimento  \
# 1720              2015   2015-05-15T16:24:37Z
#
#       Identificatore in OpenStreetMap  Longitudine  Latitudine
# 1720                       1409092156    10.433494   43.723447

# %%
anni = pub["Anno inserimento"].sort_values().unique()

# %%
anni
# Out:
# array([2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016])

# %%
for nome in pub["Nome"]:
    nome = str(nome) # risolve il problema dati nulli
    nome = nome.lower() # evito la discriminante di "Enoteca" ed "enoteca"
    if ("enoteca" in nome) or ("vino" in nome) or ("vini" in nome) or ("vineria" in nome) or ("wine" in nome): # metto tutte le possibili parole chiave che mi vengono in mente
        print(nome)
# Out:
# enoteca con cucina""tirolin""
# vineria del pozzo
# ai troeggi (vino, birra e bruschette)
# il dodo beer wine and food
# concordia enoteca
# wine & cofee sound
# enoteca umberto
# vinile disco pub
# cortivo risto wine pub
# enoteca ""al brindisi""
# enoteca ""da massimo""
# vinile lato b
# la volpe e l'uva winebar
# enoteca il violino rosso
# bar vineria la combriccola
# sottosopra food beer and wine
# sottosopra food beer and wine
# vini e cucina blasi
# vini e cucina blasi
# vini e olii
# vini e olii
# grotta del vino
# rossodivino
# beer & wine shop
