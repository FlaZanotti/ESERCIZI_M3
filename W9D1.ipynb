# %% [markdown]
# ## ESERCIZIO 1 e 2
#
# Abbiamo 25 studenti; memorizzare questo dato in una variabile e stamparla a video.

# %%
num_studenti=25

# %%
print(num_studenti)
# Out:
# 25

# %% [markdown]
# ## ESERCIZIO 3
#
# Arrivano altri 3 studenti; memorizzare questo dato in un'altra variabile.

# %%
studenti_new=3

# %%
print(studenti_new)
# Out:
# 3

# %% [markdown]
# ## ESERCIZIO 4:
#
# Abbiamo 25 studenti; memorizzare questo dato in una variabile.
#
# Arrivano altri 3 studenti; memorizzare questo dato in un'altra variabile.
#
# Creare un'altra variabile ancora che conterrà la somma delle prime due, poi stamparla a video.

# %%
num_studenti_new=num_studenti + studenti_new

# %%
print(num_studenti_new)
# Out:
# 28

# %% [markdown]
# ## ESERCIZIO 5
# Creare una variabile che contiene la stringa "Epicode", quindi stamparla a video.

# %%
school="Epicode"

# %%
print(school)
# Out:
# Epicode

# %% [markdown]
# ## ESERCIZIO 6
#
# Abbiamo la variabile: x = 10
# Incrementarla di 2 e poi moltiplicarla per 3
# stampare tutti i passaggi a video.

# %%
x = 10

# %%
print(x+2)
# Out:
# 12

# %%
print((x+2)*3)
# Out:
# 36

# %% [markdown]
# ## ESERCIZIO 7
#
# Creiamo le seguenti stringhe, e per ognuna di esse stampiamo a video la lunghezza con la funzione len():
#
# - str1 = "Windows"
# - str2 = "Excel"
# - str3 = "Powerpoint"
# - str4 = "Word"

# %%
str1="Windows"
str2="Excel"
str3="Powerpoint"
str4="Word"

# %%
print(len(str1))
# Out:
# 7

# %%
print(len(str2))
# Out:
# 5

# %%
print(len(str3))
# Out:
# 10

# %%
print(len(str4))
# Out:
# 4

# %% [markdown]
# ## ESERCIZIO 8
#
# Calcolare e stampare a video quanti secondi ci sono in un anno non bisestile.

# %%
tot_giorni_anno = 365

# %%
tot_ore_al_giorno = 24

# %%
tot_minuti_in_un_ora = 60

# %%
tot_secondi_in_un_minuto = 60

# %%
tot_secondi_anno_non_bisestile = tot_secondi_in_un_minuto * tot_minuti_in_un_ora * tot_ore_al_giorno * tot_giorni_anno

# %%
print(tot_secondi_anno_non_bisestile)
# Out:
# 31536000

# %% [markdown]
# ## ESERCIZIO 9
#
# Abbiamo la seguente stringa:
#
# my_string = "I am studying Python"
#
# - Trasformarla in modo che tutti i caratteri siano maiuscoli (uppercase)
# - Trasformarla in modo che tutti i caratteri siano minuscoli (lowercase)
# - Sostituire la sottostringa "Python" con la stringa "a lot"
# - Usare il metodo .strip(); cambia qualcosa? Perché? *Non cambia nulla perchè la funzione toglie gli spazi ad inizio e fine stringa. In questo caso anche l'originale non aveva spazi ad inizio e fine, perciò nothing change*
# - Usare il metodo .split() per trovare tutte le parole (token)

# %%
my_string="I am studying Python"

# %%
my_string.lower()
# Out:
# 'i am studying python'

# %%
my_string.upper()
# Out:
# 'I AM STUDYING PYTHON'

# %%
my_string.replace("Python","a lot")
# Out:
# 'I am studying a lot'

# %%
my_string.strip()
# Out:
# 'I am studying Python'

# %%
my_string.split()
# Out:
# ['I', 'am', 'studying', 'Python']

# %% [markdown]
# ## ESERCIZIO 10
#
# Abbiamo due liste, una di studenti e una di corsi:
#
# studenti = ["Alex", "Bob", "Cindy", "Dan", "Emma", "Faith", "Grace", "Henry"]
#
# corsi = ["Cybersecurity", "Data Analyst", "Backend", "Frontend", "Data Analyst", "Backend"]
#
# Tenendo conto che i dati sono in corrispondenza posizionale, leggiamo con attenzione le due liste.
#
# - Sapendo che Emma segue Data Analyst
# - Faith segue Backend
# - Grace segue Frontend
# - Henry segue Cybersecurity
#
#   verifichiamo quali dati mancano, aggiungiamo i dati mancanti uno alla volta con il metodo .append()

# %%
studenti = ["Alex", "Bob", "Cindy", "Dan", "Emma", "Faith", "Grace", "Henry"]
corsi = ["Cybersecurity", "Data Analyst", "Backend", "Frontend", "Data Analyst", "Backend"]

# %%
# aggiungiamo i corsi mancanti uno alla volta
corsi.append("Frontend")        # per Grace
corsi.append("Cybersecurity")   # per Henry

# %%
print(corsi)
# Out:
# ['Cybersecurity', 'Data Analyst', 'Backend', 'Frontend', 'Data Analyst', 'Backend', 'Frontend', 'Cybersecurity']

# %%
len(studenti)==len(corsi) #verifco che n°studenti = n°corsi
# Out:
# True
